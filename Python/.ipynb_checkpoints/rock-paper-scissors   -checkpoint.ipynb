# %%
#rock, paper or scissors game
import time
import random
game = ['rock', 'paper', 'scissors']
upoints = 0
cpoints = 0



print("Hello my name is Jarvas \n"
"I am a programmed computer to play 'rock, paper or scissors' against you!\n")
time.sleep(5)
user = input("What's your name: ")
time.sleep(2)
print("Ok",user, "the Rules of Rock paper scissor game will be the following: ")
time.sleep(4)
print("You have 3 options: ")
time.sleep(3)
print("Rock \n"
"Paper \n"
"Scissors \n")
time.sleep(3)
print("")
print("Pick one of the 3 \n"
"And then let the computer pick randomly also one of the 3\n"
"\n")
time.sleep(6)
print("Here are all the scenarios:") 
time.sleep(3)
print("Rock vs paper --> paper wins \n"
"Rock vs scissor --> Rock wins \n"
"paper vs scissor --> scissor wins \n")

print("Let's start?")
time.sleep(2)
start = input('Type "play" to begin: ')

time.sleep(2)
print("Hello", user)
time.sleep(2)
print("Make your choice!")
time.sleep(2)
print('"Make sure to speel it correctly! Without any capital latters!"')
time.sleep(3)
while start == "play":
    choice = input("rock, paper or scissors? ")
    time.sleep(2)
    print("Your choice is:", choice)
    time.sleep(3)
    print("OK! Now is my turn!")

    value = random.choice(game)
    print("")
    time.sleep(3)
    print("I choose",value)
    time.sleep(4)

    if value == "rock" and choice == "paper":
        print(user,"wins! Congratulations!")
        upoints += 1
    elif value == "rock" and choice == "scissors":
        print("I won!")
        cpoints += 1
    elif value == "paper" and choice == "scissors":
        print(user,"wins! Congratulations!")   
        upoints += 1
    if value == "paper" and choice == "rock":
        print("I won!")
        cpoints += 1
    elif value == "scissors" and choice == "rock":
        print(user,"wins! Congratulations!")
        upoints += 1
    elif value == "scissors" and choice == "paper":
        print("I won!")
        cpoints += 1
    elif value == choice: 
        print("It was a tie! Lets try again!")
    start = ("not")
    time.sleep(1)
    if upoints > 1 or upoints == 0:
        print("You won",upoints,"times!")
    elif upoints == 1:
        print("You won",upoints,"time!")
    if cpoints > 1 or cpoints == 0:
        print("I won",cpoints,"times!")
    elif cpoints == 1:
        print("I won",cpoints,"time!")
    time.sleep(2)    
    start = input('Type "play" to play it again or type "end" to stop playing: ')
    time.sleep(2)
    if start == "end": 
        print("")
        print("")
        print("Thank you for playing!")
        print("Here are the score:")
        print("")
        print("")
        print("Computer:", cpoints, "points!")
        print(user,':', upoints, "points!")
# Out:
# Hello my name is Jarvas
# I am a programmed computer to play 'rock, paper or scissors' against you!
#
# What's your name: Lucas
# Ok Lucas the Rules of Rock paper scissor game will be the following:
# You have 3 options:
# Rock
# Paper
# Scissors
#
#
# Pick one of the 3
# And then let the computer pick randomly also one of the 3
#
#
# Here are all the scenarios:
# Rock vs paper --> paper wins
# Rock vs scissor --> Rock wins
# paper vs scissor --> scissor wins
#
# Let's start?
# Type "play" to begin: play
# Hello Lucas
# Make your choice!
# "Make sure to speel it correctly! Without any capital latters!"
# rock, paper or scissors? rock
# Your choice is: rock
# OK! Now is my turn!
#
# I choose rock
# It was a tie! Lets try again!
# You won 0 times!
# I won 0 times!
# Type "play" to play it again or type "end" to stop playing: end
#
#
# Thank for playing!
# Here are the score:
#
#
# Computer: 0 points!
# Lucas : 0 points!
